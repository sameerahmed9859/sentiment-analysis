# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from string import punctuation
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re



import warnings
warnings.filterwarnings('ignore')

#pd.set_option('display.max_rows',None)

# %%
df=pd.read_csv('t.csv',delimiter=',', encoding='ISO-8859-1')
df.head()
# Out:
#    polarity of tweet   id of the tweet             date of the tweet  \
# 0                   0       1467810672  Mon Apr 06 22:19:49 PDT 2009
# 1                   0       1467810917  Mon Apr 06 22:19:53 PDT 2009
# 2                   0       1467811184  Mon Apr 06 22:19:57 PDT 2009
# 3                   0       1467811193  Mon Apr 06 22:19:57 PDT 2009
# 4                   0       1467811372  Mon Apr 06 22:20:00 PDT 2009
#
#       query           user                                 text of the tweet
# 0  NO_QUERY  scotthamilton  is upset that he can't update his Facebook by ...
# 1  NO_QUERY       mattycus  @Kenichan I dived many times for the ball. Man...
# 2  NO_QUERY        ElleCTF    my whole body feels itchy and like its on fire
# 3  NO_QUERY         Karoli  @nationwideclass no, it's not behaving at all....
# 4  NO_QUERY       joy_wolf                      @Kwesidei not the whole crew

# %%
df.columns = ['Sentiment','id','date','query','user','text']
df.head()
# Out:
#    Sentiment          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
#
#             user                                               text
# 0  scotthamilton  is upset that he can't update his Facebook by ...
# 1       mattycus  @Kenichan I dived many times for the ball. Man...
# 2        ElleCTF    my whole body feels itchy and like its on fire
# 3         Karoli  @nationwideclass no, it's not behaving at all....
# 4       joy_wolf                      @Kwesidei not the whole crew

# %%
df = df[['Sentiment','text']]
df.columns
# Out:
# Index(['Sentiment', 'text'], dtype='object')

# %%
df.Sentiment.value_counts()
# Out:
# 0    799996
# 1    248576
# Name: Sentiment, dtype: int64

# %%
df['Sentiment'] = df['Sentiment'].replace(4,1)

# %%
a=df['Sentiment'].value_counts().sort_index().plot(kind='bar',title="review by customer",figsize=(10,5))
a.set_xlabel("Count")
plt.show()

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
# The data is unbalanced therfore we will downsample the data to have same count for each sentiment

# %%
from sklearn.utils import resample
## majority class 0
df_majority = df[df['Sentiment']==0]
## minority class 1
df_minority = df[df['Sentiment']==1]
df_minority.shape
# Out:
# (248576, 2)

# %%
df_majority_downsampled = resample(df_majority, 
                                 replace=False,   
                                 n_samples=len(df_minority),    
                                 random_state=1234) 
df = df_majority_downsampled.append(df_minority)
df.head()
# Out:
#         Sentiment                                               text
# 74567           0  Wow slept for almost 12hours. Sleepy me!! Uni ...
# 668722          0  gets bored with an idea too easily ... like tw...
# 286706          0  To my girls - sorry i've been a homebody latel...
# 632911          0  BK once again for the weekend...If it wasnt fo...
# 356735          0  @DonnieWahlberg Now why didn't you do that las...

# %%
df['Sentiment'].value_counts().sort_index().plot(kind='bar',title="review by customer",figsize=(10,5))
# Out:
# <Axes: title={'center': 'review by customer'}>

# %%
stuff_to_be_removed = list(stopwords.words('english'))+list(punctuation)
stemmer = LancasterStemmer()

corpus = df['text'].tolist()
print(len(corpus))
print(corpus[3])
# Out:
# 497152
# Wow slept for almost 12hours. Sleepy me!! Uni now, boo! I wanna stay home, drink tea and watch house...

# %%
# %%time
final_corpus = []
final_corpus_joined = []
for i in df.index:

    text = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    #Convert to lowercase
    text = text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()

    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text 
            if not word in stuff_to_be_removed] 
    text1 = " ".join(text)
    final_corpus.append(text)
    final_corpus_joined.append(text1)
# Out:
# CPU times: total: 1min 25s
# Wall time: 1min 25s

# %%
#Storing the cleaned data seperately

data_cleaned = pd.DataFrame()
data_cleaned["text"] = final_corpus_joined
data_cleaned["Sentiment"] = df["Sentiment"].values
data_cleaned['Sentiment'].value_counts()
# Out:
# 0    248576
# 1    248576
# Name: Sentiment, dtype: int64

# %%
data_eda = pd.DataFrame()
data_eda['text'] = final_corpus
data_eda['Sentiment'] = df["Sentiment"].values
data_eda.head()
# Out:
#                                                 text  Sentiment
# 0  [wow, slept, almost, hour, sleepy, uni, boo, w...          0
# 1          [get, bored, idea, easily, like, twitter]          0
# 2  [girl, sorry, homebody, lately, dont, feel, we...          0
# 3              [bk, weekend, wasnt, puppy, stay, as]          0
# 4             [donniewahlberg, last, night, atlanta]          0

# %%
# Storing positive data seperately
positive = data_eda[data_eda['Sentiment'] == 1]
positive_list = positive['text'].tolist()

# Storing negative data seperately

negative = data_eda[data_eda['Sentiment'] == 0]
negative_list = negative['text'].tolist()

positive_all = " ".join([word for sent in positive_list for word in sent ])
negative_all = " ".join([word for sent in negative_list for word in sent ])

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(positive_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("Positive")
plt.show()

# %%
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(negative_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("negative")
plt.show()

# %%
vectorization=TfidfVectorizer()

# %%
x=vectorization.fit_transform(data_cleaned['text'])
y=data_cleaned['Sentiment']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()

# %%
LR.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
LR.score(xtest, ytest)
# Out:
# 0.7756158395129604

# %%
pred_lr=LR.predict(xtest)

# %%
print('accuracy score:',accuracy_score(ytest,pred_lr))
print('classification_report:\n' , classification_report(ytest,pred_lr))
# Out:
# accuracy score: 0.7756158395129604
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     74753
#            1       0.76      0.80      0.78     74393
#
#     accuracy                           0.78    149146
#    macro avg       0.78      0.78      0.78    149146
# weighted avg       0.78      0.78      0.78    149146

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MN=MultinomialNB()

# %%
MN.fit(xtrain,ytrain)
# Out:
# MultinomialNB()

# %%
MN.score(xtest,ytest)
# Out:
# 0.7607310957048797

# %%
mn_pred=MN.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print('accuracy score:',accuracy_score(ytest,mn_pred))
# Out:
# accuracy score: 0.7607310957048797

# %%
print('classification_report:\n' , classification_report(ytest,mn_pred))
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77     74753
#            1       0.78      0.73      0.75     74393
#
#     accuracy                           0.76    149146
#    macro avg       0.76      0.76      0.76    149146
# weighted avg       0.76      0.76      0.76    149146

# %%
from sklearn.svm import LinearSVC

# %%
LC=LinearSVC()

# %%
LC.fit(xtrain,ytrain)
# Out:
# LinearSVC()

# %%
LC.score(xtest,ytest)
# Out:
# 0.7711705308891958

# %%
lc_pred_y=LC.predict(xtrain)

# %%
print('accuracy score:',accuracy_score(ytrain,lc_pred_y))
# Out:
# accuracy score: 0.9004068895363873

# %%
lc_pred=LC.predict(xtest)

# %%
print('accuracy score:',accuracy_score(ytest,lc_pred))
print('classification_report:\n' , classification_report(ytest,lc_pred))
# Out:
# accuracy score: 0.7711705308891958
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     74753
#            1       0.76      0.78      0.77     74393
#
#     accuracy                           0.77    149146
#    macro avg       0.77      0.77      0.77    149146
# weighted avg       0.77      0.77      0.77    149146

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# %%
PA=PassiveAggressiveClassifier()

# %%
PA.fit(xtrain,ytrain)
# Out:
# PassiveAggressiveClassifier()

# %%
pa_pre_Y=PA.predict(xtrain)

# %%
pa_pred=PA.predict(xtest)

# %%
print('classification_report:\n' , classification_report(ytrain,pa_pre_Y))
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91    173823
#            1       0.91      0.90      0.90    174183
#
#     accuracy                           0.91    348006
#    macro avg       0.91      0.91      0.91    348006
# weighted avg       0.91      0.91      0.91    348006

# %%
print('classification_report:\n' , classification_report(ytest,pa_pred))
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74     74753
#            1       0.75      0.71      0.73     74393
#
#     accuracy                           0.74    149146
#    macro avg       0.74      0.74      0.74    149146
# weighted avg       0.74      0.74      0.74    149146

# %%
# we can see that the logistic regression model performed better on the test data when compared to other model
